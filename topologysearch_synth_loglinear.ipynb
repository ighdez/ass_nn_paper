# %%
# Load modules
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 

import numpy as np
import pandas as pd
from train_ann_functions import AsuSharedNN, ll, normaliser_shared
import matplotlib.pyplot as plt

# %%
# Load data
data_train = pd.read_csv('data/data_rum_4_train.csv')
data_test = pd.read_csv('data/data_rum_4_test.csv')

# %%
# Set scalars
J = 3
K = 2

# Set variables
Xvars = ['TRAIN_COST','TRAIN_TT','SM_COST','SM_TT','CAR_COST','CAR_TT']
X_train = data_train[Xvars]
X_test = data_test[Xvars]
X = pd.concat([X_train,X_test],axis=0)

transformer = normaliser_shared(X_shared = [1,0,1,0,1,0],shared_locations = [[0,2,4]])
transformer.fit(X)

X_train = transformer.transform(X_train)
X_test = transformer.transform(X_test)
X = transformer.transform(X)

y_train = data_train['CHOICE'].to_numpy() - 1
y_test = data_test['CHOICE'].to_numpy() - 1
y = np.r_[y_train,y_test]

# %%
# Select number of trainings and topologies
R = 10
network_topologies = [(5,),(6,),(7,),(8,),(9,),(10,),(15,),(20,),(30,),(5,5),(10,10),(20,20),(30,30)]

# %%
# Save results
t_list = []
lfull_list = []
ltest_list = []
r2_list = []
# Loop among topologies and repetitions

for t in network_topologies:
    for r in range(R):

        # Set model
        model = AsuSharedNN(topology=t,activation='tanh',from_logits=False)
        model.fit(X_train,y_train,[1,1,2,2,3,3],[1,0,1,0,1,0],early_stopping=True,validation_split=0.1)
        # Get log-likelihood
        ll_full = ll(y,model.predict_proba(X))
        ll_test = ll(y_test,model.predict_proba(X_test))
        r2_test = 1-ll_test/(len(X_test)*np.log(1/J))

        # Store current ll and topology
        t_list.append(str(t))
        lfull_list.append(ll_full)
        ltest_list.append(ll_test)
        r2_list.append(r2_test)
        print('NN ' + str(t) + ' / Rep. ' + str(r+1) + ': LL (full) = ' + str(round(ll_full,2))  + ' / LL (test) = ' + str(round(ll_test,2)) + ' / Rho-sq (test): ' + str(round(r2_test,4)))
# Out:
# NN (5,) / Rep. 1: LL (full) = -4513.03 / LL (test) = -933.42 / Rho-sq (test): 0.5301
# NN (5,) / Rep. 2: LL (full) = -4520.39 / LL (test) = -934.38 / Rho-sq (test): 0.5296
# NN (5,) / Rep. 3: LL (full) = -4525.07 / LL (test) = -935.42 / Rho-sq (test): 0.5291
# NN (5,) / Rep. 4: LL (full) = -4523.93 / LL (test) = -935.61 / Rho-sq (test): 0.529
# NN (5,) / Rep. 5: LL (full) = -4547.67 / LL (test) = -938.01 / Rho-sq (test): 0.5278
# NN (5,) / Rep. 6: LL (full) = -4541.2 / LL (test) = -937.58 / Rho-sq (test): 0.528
# NN (5,) / Rep. 7: LL (full) = -4509.86 / LL (test) = -932.82 / Rho-sq (test): 0.5304
# NN (5,) / Rep. 8: LL (full) = -4540.72 / LL (test) = -937.79 / Rho-sq (test): 0.5279
# NN (5,) / Rep. 9: LL (full) = -4536.51 / LL (test) = -937.04 / Rho-sq (test): 0.5282
# NN (8,) / Rep. 6: LL (full) = -4550.25 / LL (test) = -939.84 / Rho-sq (test): 0.5268
# NN (8,) / Rep. 7: LL (full) = -4555.7 / LL (test) = -940.82 / Rho-sq (test): 0.5263
# NN (8,) / Rep. 8: LL (full) = -4578.33 / LL (test) = -944.21 / Rho-sq (test): 0.5246
# NN (8,) / Rep. 9: LL (full) = -4556.59 / LL (test) = -940.85 / Rho-sq (test): 0.5263
# NN (8,) / Rep. 10: LL (full) = -4543.37 / LL (test) = -938.32 / Rho-sq (test): 0.5276
# NN (9,) / Rep. 1: LL (full) = -4539.73 / LL (test) = -937.85 / Rho-sq (test): 0.5278
# NN (9,) / Rep. 2: LL (full) = -4558.35 / LL (test) = -940.78 / Rho-sq (test): 0.5264
# NN (9,) / Rep. 3: LL (full) = -4571.64 / LL (test) = -943.13 / Rho-sq (test): 0.5252
# NN (9,) / Rep. 4: LL (full) = -4555.6 / LL (test) = -940.19 / Rho-sq (test): 0.5267
# NN (9,) / Rep. 5: LL (full) = -4560.33 / LL (test) = -941.66 / Rho-sq (test): 0.5259
# NN (9,) / Rep. 6: LL (full) = -4550.31 / LL (test) = -939.66 / Rho-sq (test): 0.5269
# NN (9,) / Rep. 7: LL (full) = -4553.42 / LL (test) = -939.43 / Rho-sq (test): 0.527
# NN (9,) / Rep. 8: LL (full) = -4572.65 / LL (test) = -943.11 / Rho-sq (test): 0.5252
# NN (9,) / Rep. 9: LL (full) = -4577.4 / LL (test) = -943.86 / Rho-sq (test): 0.5248
# NN (9,) / Rep. 10: LL (full) = -4550.01 / LL (test) = -939.77 / Rho-sq (test): 0.5269
# NN (10,) / Rep. 1: LL (full) = -4569.06 / LL (test) = -942.42 / Rho-sq (test): 0.5255
# NN (10,) / Rep. 2: LL (full) = -4546.28 / LL (test) = -938.73 / Rho-sq (test): 0.5274
# NN (10,) / Rep. 3: LL (full) = -4537.91 / LL (test) = -937.53 / Rho-sq (test): 0.528
# NN (10,) / Rep. 4: LL (full) = -4552.91 / LL (test) = -939.91 / Rho-sq (test): 0.5268
# NN (10,) / Rep. 5: LL (full) = -4550.5 / LL (test) = -939.72 / Rho-sq (test): 0.5269
# NN (10,) / Rep. 6: LL (full) = -4561.33 / LL (test) = -941.75 / Rho-sq (test): 0.5259
# NN (10,) / Rep. 7: LL (full) = -4560.14 / LL (test) = -941.38 / Rho-sq (test): 0.5261
# NN (10,) / Rep. 8: LL (full) = -4562.25 / LL (test) = -941.31 / Rho-sq (test): 0.5261
# NN (10,) / Rep. 9: LL (full) = -4590.85 / LL (test) = -946.4 / Rho-sq (test): 0.5235
# NN (10,) / Rep. 10: LL (full) = -4539.17 / LL (test) = -938.27 / Rho-sq (test): 0.5276
# NN (15,) / Rep. 1: LL (full) = -4575.51 / LL (test) = -944.05 / Rho-sq (test): 0.5247
# NN (30,) / Rep. 8: LL (full) = -4576.52 / LL (test) = -943.02 / Rho-sq (test): 0.5252
# NN (30,) / Rep. 9: LL (full) = -4621.1 / LL (test) = -951.44 / Rho-sq (test): 0.521
# NN (30,) / Rep. 10: LL (full) = -4678.59 / LL (test) = -961.54 / Rho-sq (test): 0.5159
# NN (5, 5) / Rep. 1: LL (full) = -4463.56 / LL (test) = -922.65 / Rho-sq (test): 0.5355
# NN (5, 5) / Rep. 2: LL (full) = -4460.55 / LL (test) = -922.34 / Rho-sq (test): 0.5356
# NN (5, 5) / Rep. 3: LL (full) = -4468.66 / LL (test) = -923.26 / Rho-sq (test): 0.5352
# NN (5, 5) / Rep. 4: LL (full) = -4460.84 / LL (test) = -922.6 / Rho-sq (test): 0.5355
# NN (5, 5) / Rep. 5: LL (full) = -4464.34 / LL (test) = -922.57 / Rho-sq (test): 0.5355
# NN (5, 5) / Rep. 6: LL (full) = -4460.83 / LL (test) = -922.12 / Rho-sq (test): 0.5358
# NN (5, 5) / Rep. 7: LL (full) = -4458.68 / LL (test) = -922.25 / Rho-sq (test): 0.5357
# NN (5, 5) / Rep. 8: LL (full) = -4467.22 / LL (test) = -923.31 / Rho-sq (test): 0.5352
# NN (5, 5) / Rep. 9: LL (full) = -4454.07 / LL (test) = -921.92 / Rho-sq (test): 0.5359
# NN (5, 5) / Rep. 10: LL (full) = -4462.01 / LL (test) = -922.5 / Rho-sq (test): 0.5356
# NN (10, 10) / Rep. 1: LL (full) = -4455.74 / LL (test) = -922.33 / Rho-sq (test): 0.5356
# NN (10, 10) / Rep. 2: LL (full) = -4449.22 / LL (test) = -921.47 / Rho-sq (test): 0.5361
# NN (10, 10) / Rep. 3: LL (full) = -4465.75 / LL (test) = -923.02 / Rho-sq (test): 0.5353
# NN (10, 10) / Rep. 4: LL (full) = -4458.93 / LL (test) = -922.74 / Rho-sq (test): 0.5354
# NN (10, 10) / Rep. 5: LL (full) = -4471.79 / LL (test) = -923.48 / Rho-sq (test): 0.5351
# NN (10, 10) / Rep. 6: LL (full) = -4455.72 / LL (test) = -921.97 / Rho-sq (test): 0.5358
# NN (10, 10) / Rep. 7: LL (full) = -4459.73 / LL (test) = -922.4 / Rho-sq (test): 0.5356
# NN (10, 10) / Rep. 8: LL (full) = -4455.21 / LL (test) = -921.99 / Rho-sq (test): 0.5358
# NN (10, 10) / Rep. 9: LL (full) = -4451.96 / LL (test) = -921.25 / Rho-sq (test): 0.5362
# NN (10, 10) / Rep. 10: LL (full) = -4460.61 / LL (test) = -922.39 / Rho-sq (test): 0.5356
# NN (20, 20) / Rep. 1: LL (full) = -4454.44 / LL (test) = -921.73 / Rho-sq (test): 0.536
# NN (20, 20) / Rep. 2: LL (full) = -4450.01 / LL (test) = -921.38 / Rho-sq (test): 0.5361
# NN (20, 20) / Rep. 3: LL (full) = -4460.18 / LL (test) = -922.94 / Rho-sq (test): 0.5353
# NN (20, 20) / Rep. 4: LL (full) = -4466.54 / LL (test) = -923.85 / Rho-sq (test): 0.5349
# NN (20, 20) / Rep. 5: LL (full) = -4452.31 / LL (test) = -921.41 / Rho-sq (test): 0.5361
# NN (20, 20) / Rep. 6: LL (full) = -4466.41 / LL (test) = -925.2 / Rho-sq (test): 0.5342
# NN (20, 20) / Rep. 7: LL (full) = -4457.16 / LL (test) = -922.82 / Rho-sq (test): 0.5354
# NN (20, 20) / Rep. 8: LL (full) = -4457.61 / LL (test) = -922.89 / Rho-sq (test): 0.5354
# NN (20, 20) / Rep. 9: LL (full) = -4459.32 / LL (test) = -922.98 / Rho-sq (test): 0.5353
# NN (20, 20) / Rep. 10: LL (full) = -4454.97 / LL (test) = -922.11 / Rho-sq (test): 0.5358
# NN (30, 30) / Rep. 1: LL (full) = -4468.64 / LL (test) = -924.34 / Rho-sq (test): 0.5346
# NN (30, 30) / Rep. 2: LL (full) = -4447.57 / LL (test) = -921.08 / Rho-sq (test): 0.5363
# NN (30, 30) / Rep. 3: LL (full) = -4451.3 / LL (test) = -921.47 / Rho-sq (test): 0.5361
# NN (30, 30) / Rep. 4: LL (full) = -4461.41 / LL (test) = -924.52 / Rho-sq (test): 0.5345
# NN (30, 30) / Rep. 5: LL (full) = -4456.24 / LL (test) = -921.54 / Rho-sq (test): 0.5361
# NN (30, 30) / Rep. 6: LL (full) = -4469.24 / LL (test) = -925.34 / Rho-sq (test): 0.5341
# NN (30, 30) / Rep. 7: LL (full) = -4495.8 / LL (test) = -930.02 / Rho-sq (test): 0.5318
# NN (30, 30) / Rep. 8: LL (full) = -4448.99 / LL (test) = -921.32 / Rho-sq (test): 0.5362
# NN (30, 30) / Rep. 9: LL (full) = -4443.48 / LL (test) = -920.26 / Rho-sq (test): 0.5367
# NN (30, 30) / Rep. 10: LL (full) = -4449.39 / LL (test) = -921.04 / Rho-sq (test): 0.5363

# %%
results = pd.DataFrame(np.c_[t_list,lfull_list,ltest_list],columns=['Topology','LL (full)','LL (test)'])
results.to_csv('tables/topology_4_asushared.csv')

# %%
ll_test_df = pd.DataFrame(np.array(ltest_list).reshape((len(network_topologies),R)).T,columns=network_topologies)
r2_df = pd.DataFrame(np.array(r2_list).reshape((len(network_topologies),R)).T,columns=network_topologies)
ll_full_df = pd.DataFrame(np.array(lfull_list).reshape((len(network_topologies),R)).T,columns=network_topologies)

fig, (ax1, ax2, ax3) = plt.subplots(3,1,figsize=(10,15))

ax1.boxplot(ll_test_df,showfliers=False,showmeans=True,labels=ll_test_df.columns)
ax1.set_title('Test')

ax2.boxplot(r2_df,showfliers=False,showmeans=True,labels=r2_df.columns)
ax2.set_title('Rho-squared')

ax3.boxplot(ll_full_df,showfliers=False,showmeans=True,labels=ll_full_df.columns)
ax3.set_title('Full')

plt.show()
