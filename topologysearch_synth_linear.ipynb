# %%
# Load modules
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 

import numpy as np
import pandas as pd
from train_ann_functions import AsuSharedNN, ll, normaliser_shared
import matplotlib.pyplot as plt

# %%
# Load data
data_train = pd.read_csv('data/data_rum_1_train.csv')
data_test = pd.read_csv('data/data_rum_1_test.csv')

# %%
# Set scalars
J = 3
K = 2

# Set variables
Xvars = ['TRAIN_COST','TRAIN_TT','SM_COST','SM_TT','CAR_COST','CAR_TT']
X_train = data_train[Xvars]
X_test = data_test[Xvars]
X = pd.concat([X_train,X_test],axis=0)

transformer = normaliser_shared(X_shared = [1,0,1,0,1,0],shared_locations = [[0,2,4]])
transformer.fit(X)

X_train = transformer.transform(X_train)
X_test = transformer.transform(X_test)
X = transformer.transform(X)

y_train = data_train['CHOICE'].to_numpy() - 1
y_test = data_test['CHOICE'].to_numpy() - 1
y = np.r_[y_train,y_test]

# %%
# Select number of trainings and topologies
R = 10
network_topologies = [(5,),(6,),(7,),(8,),(9,),(10,),(15,),(20,),(30,),(5,5),(10,10),(20,20),(30,30)]

# %%
# Save results
t_list = []
lfull_list = []
ltest_list = []
r2_list = []
# Loop among topologies and repetitions

for t in network_topologies:
    for r in range(R):

        # Set model
        model = AsuSharedNN(topology=t,activation='tanh',from_logits=False)
        model.fit(X_train,y_train,[1,1,2,2,3,3],[1,0,1,0,1,0],early_stopping=True,validation_split=0.1)
        # Get log-likelihood
        ll_full = ll(y,model.predict_proba(X))
        ll_test = ll(y_test,model.predict_proba(X_test))
        r2_test = 1-ll_test/(len(X_test)*np.log(1/J))

        # Store current ll and topology
        t_list.append(str(t))
        lfull_list.append(ll_full)
        ltest_list.append(ll_test)
        r2_list.append(r2_test)
        print('NN ' + str(t) + ' / Rep. ' + str(r+1) + ': LL (full) = ' + str(round(ll_full,2))  + ' / LL (test) = ' + str(round(ll_test,2)) + ' / Rho-sq (test): ' + str(round(r2_test,4)))
# Out:
# NN (5,) / Rep. 1: LL (full) = -5833.04 / LL (test) = -1188.09 / Rho-sq (test): 0.4019
# NN (5,) / Rep. 2: LL (full) = -5825.8 / LL (test) = -1187.5 / Rho-sq (test): 0.4022
# NN (5,) / Rep. 3: LL (full) = -5819.63 / LL (test) = -1186.68 / Rho-sq (test): 0.4026
# NN (5,) / Rep. 4: LL (full) = -5827.22 / LL (test) = -1188.21 / Rho-sq (test): 0.4018
# NN (5,) / Rep. 5: LL (full) = -5812.91 / LL (test) = -1185.81 / Rho-sq (test): 0.403
# NN (5,) / Rep. 6: LL (full) = -5818.69 / LL (test) = -1186.2 / Rho-sq (test): 0.4028
# NN (5,) / Rep. 7: LL (full) = -5819.0 / LL (test) = -1185.84 / Rho-sq (test): 0.403
# NN (5,) / Rep. 8: LL (full) = -5819.49 / LL (test) = -1185.94 / Rho-sq (test): 0.4029
# NN (5,) / Rep. 9: LL (full) = -5823.75 / LL (test) = -1186.88 / Rho-sq (test): 0.4025
# NN (5,) / Rep. 10: LL (full) = -5823.38 / LL (test) = -1186.46 / Rho-sq (test): 0.4027
# NN (6,) / Rep. 1: LL (full) = -5819.17 / LL (test) = -1186.68 / Rho-sq (test): 0.4026
# NN (6,) / Rep. 2: LL (full) = -5817.32 / LL (test) = -1186.61 / Rho-sq (test): 0.4026
# NN (6,) / Rep. 3: LL (full) = -5815.75 / LL (test) = -1186.12 / Rho-sq (test): 0.4028
# NN (6,) / Rep. 4: LL (full) = -5818.47 / LL (test) = -1186.45 / Rho-sq (test): 0.4027
# NN (6,) / Rep. 5: LL (full) = -5813.18 / LL (test) = -1186.39 / Rho-sq (test): 0.4027
# NN (6,) / Rep. 6: LL (full) = -5817.41 / LL (test) = -1186.72 / Rho-sq (test): 0.4025
# NN (6,) / Rep. 7: LL (full) = -5816.46 / LL (test) = -1186.53 / Rho-sq (test): 0.4026
# NN (6,) / Rep. 8: LL (full) = -5822.62 / LL (test) = -1187.78 / Rho-sq (test): 0.402
# NN (6,) / Rep. 9: LL (full) = -5818.48 / LL (test) = -1186.63 / Rho-sq (test): 0.4026
# NN (6,) / Rep. 10: LL (full) = -5814.23 / LL (test) = -1186.28 / Rho-sq (test): 0.4028
# NN (7,) / Rep. 1: LL (full) = -5817.26 / LL (test) = -1187.47 / Rho-sq (test): 0.4022
# NN (7,) / Rep. 2: LL (full) = -5810.68 / LL (test) = -1185.42 / Rho-sq (test): 0.4032
# NN (7,) / Rep. 3: LL (full) = -5813.96 / LL (test) = -1186.53 / Rho-sq (test): 0.4026
# NN (7,) / Rep. 4: LL (full) = -5819.4 / LL (test) = -1186.88 / Rho-sq (test): 0.4025
# NN (7,) / Rep. 5: LL (full) = -5813.2 / LL (test) = -1186.21 / Rho-sq (test): 0.4028
# NN (7,) / Rep. 6: LL (full) = -5819.69 / LL (test) = -1187.22 / Rho-sq (test): 0.4023
# NN (7,) / Rep. 7: LL (full) = -5820.49 / LL (test) = -1186.71 / Rho-sq (test): 0.4025
# NN (7,) / Rep. 8: LL (full) = -5815.81 / LL (test) = -1185.54 / Rho-sq (test): 0.4031
# NN (7,) / Rep. 9: LL (full) = -5817.39 / LL (test) = -1186.62 / Rho-sq (test): 0.4026
# NN (7,) / Rep. 10: LL (full) = -5822.5 / LL (test) = -1187.53 / Rho-sq (test): 0.4021
# NN (8,) / Rep. 1: LL (full) = -5813.92 / LL (test) = -1187.17 / Rho-sq (test): 0.4023
# NN (8,) / Rep. 2: LL (full) = -5809.57 / LL (test) = -1185.64 / Rho-sq (test): 0.4031
# NN (8,) / Rep. 3: LL (full) = -5811.04 / LL (test) = -1185.38 / Rho-sq (test): 0.4032
# NN (8,) / Rep. 4: LL (full) = -5825.41 / LL (test) = -1187.65 / Rho-sq (test): 0.4021
# NN (8,) / Rep. 5: LL (full) = -5812.93 / LL (test) = -1186.26 / Rho-sq (test): 0.4028
# NN (8,) / Rep. 6: LL (full) = -5810.74 / LL (test) = -1185.35 / Rho-sq (test): 0.4032
# NN (8,) / Rep. 7: LL (full) = -5811.81 / LL (test) = -1186.09 / Rho-sq (test): 0.4029
# NN (8,) / Rep. 8: LL (full) = -5815.58 / LL (test) = -1186.13 / Rho-sq (test): 0.4028
# NN (8,) / Rep. 9: LL (full) = -5809.73 / LL (test) = -1185.62 / Rho-sq (test): 0.4031
# NN (8,) / Rep. 10: LL (full) = -5808.5 / LL (test) = -1185.75 / Rho-sq (test): 0.403
# NN (9,) / Rep. 1: LL (full) = -5810.62 / LL (test) = -1186.19 / Rho-sq (test): 0.4028
# NN (9,) / Rep. 2: LL (full) = -5811.14 / LL (test) = -1186.52 / Rho-sq (test): 0.4026
# NN (9,) / Rep. 3: LL (full) = -5811.88 / LL (test) = -1186.0 / Rho-sq (test): 0.4029
# NN (9,) / Rep. 4: LL (full) = -5813.59 / LL (test) = -1186.04 / Rho-sq (test): 0.4029
# NN (9,) / Rep. 5: LL (full) = -5812.26 / LL (test) = -1185.92 / Rho-sq (test): 0.4029
# NN (9,) / Rep. 6: LL (full) = -5812.27 / LL (test) = -1186.18 / Rho-sq (test): 0.4028
# NN (9,) / Rep. 7: LL (full) = -5814.09 / LL (test) = -1186.44 / Rho-sq (test): 0.4027
# NN (9,) / Rep. 8: LL (full) = -5810.34 / LL (test) = -1185.55 / Rho-sq (test): 0.4031
# NN (9,) / Rep. 9: LL (full) = -5822.32 / LL (test) = -1187.5 / Rho-sq (test): 0.4021
# NN (9,) / Rep. 10: LL (full) = -5809.9 / LL (test) = -1186.07 / Rho-sq (test): 0.4029
# NN (10,) / Rep. 1: LL (full) = -5815.15 / LL (test) = -1186.64 / Rho-sq (test): 0.4026
# NN (10,) / Rep. 2: LL (full) = -5811.63 / LL (test) = -1186.14 / Rho-sq (test): 0.4028
# NN (10,) / Rep. 3: LL (full) = -5819.3 / LL (test) = -1187.38 / Rho-sq (test): 0.4022
# NN (10,) / Rep. 4: LL (full) = -5812.27 / LL (test) = -1185.58 / Rho-sq (test): 0.4031
# NN (10,) / Rep. 5: LL (full) = -5808.31 / LL (test) = -1185.1 / Rho-sq (test): 0.4034
# NN (10,) / Rep. 6: LL (full) = -5807.6 / LL (test) = -1185.68 / Rho-sq (test): 0.4031
# NN (10,) / Rep. 7: LL (full) = -5810.21 / LL (test) = -1186.18 / Rho-sq (test): 0.4028
# NN (10,) / Rep. 8: LL (full) = -5813.0 / LL (test) = -1186.61 / Rho-sq (test): 0.4026
# NN (10,) / Rep. 9: LL (full) = -5809.79 / LL (test) = -1185.95 / Rho-sq (test): 0.4029
# NN (10,) / Rep. 10: LL (full) = -5814.94 / LL (test) = -1186.26 / Rho-sq (test): 0.4028
# NN (15,) / Rep. 1: LL (full) = -5807.53 / LL (test) = -1185.62 / Rho-sq (test): 0.4031
# NN (15,) / Rep. 2: LL (full) = -5806.39 / LL (test) = -1185.55 / Rho-sq (test): 0.4031
# NN (15,) / Rep. 3: LL (full) = -5807.85 / LL (test) = -1185.81 / Rho-sq (test): 0.403
# NN (15,) / Rep. 4: LL (full) = -5808.53 / LL (test) = -1186.1 / Rho-sq (test): 0.4029
# NN (15,) / Rep. 5: LL (full) = -5806.1 / LL (test) = -1185.85 / Rho-sq (test): 0.403
# NN (15,) / Rep. 6: LL (full) = -5808.15 / LL (test) = -1186.31 / Rho-sq (test): 0.4028
# NN (15,) / Rep. 7: LL (full) = -5808.22 / LL (test) = -1186.11 / Rho-sq (test): 0.4029
# NN (15,) / Rep. 8: LL (full) = -5806.58 / LL (test) = -1185.97 / Rho-sq (test): 0.4029
# NN (15,) / Rep. 9: LL (full) = -5806.07 / LL (test) = -1185.51 / Rho-sq (test): 0.4032
# NN (15,) / Rep. 10: LL (full) = -5809.82 / LL (test) = -1185.93 / Rho-sq (test): 0.4029
# NN (20,) / Rep. 1: LL (full) = -5807.96 / LL (test) = -1186.37 / Rho-sq (test): 0.4027
# NN (20,) / Rep. 2: LL (full) = -5807.69 / LL (test) = -1185.49 / Rho-sq (test): 0.4032
# NN (20,) / Rep. 3: LL (full) = -5805.5 / LL (test) = -1185.58 / Rho-sq (test): 0.4031
# NN (20,) / Rep. 4: LL (full) = -5810.84 / LL (test) = -1186.4 / Rho-sq (test): 0.4027
# NN (20,) / Rep. 5: LL (full) = -5806.25 / LL (test) = -1185.8 / Rho-sq (test): 0.403
# NN (20,) / Rep. 6: LL (full) = -5811.63 / LL (test) = -1186.29 / Rho-sq (test): 0.4028
# NN (20,) / Rep. 7: LL (full) = -5809.36 / LL (test) = -1186.15 / Rho-sq (test): 0.4028
# NN (20,) / Rep. 8: LL (full) = -5807.51 / LL (test) = -1185.67 / Rho-sq (test): 0.4031
# NN (20,) / Rep. 9: LL (full) = -5805.37 / LL (test) = -1185.61 / Rho-sq (test): 0.4031
# NN (20,) / Rep. 10: LL (full) = -5813.52 / LL (test) = -1186.89 / Rho-sq (test): 0.4025
# NN (30,) / Rep. 1: LL (full) = -5808.21 / LL (test) = -1186.52 / Rho-sq (test): 0.4026
# NN (30,) / Rep. 2: LL (full) = -5807.45 / LL (test) = -1186.74 / Rho-sq (test): 0.4025
# NN (30,) / Rep. 3: LL (full) = -5806.43 / LL (test) = -1186.21 / Rho-sq (test): 0.4028
# NN (30,) / Rep. 4: LL (full) = -5810.5 / LL (test) = -1186.9 / Rho-sq (test): 0.4025
# NN (30,) / Rep. 5: LL (full) = -5809.74 / LL (test) = -1186.68 / Rho-sq (test): 0.4026
# NN (30,) / Rep. 6: LL (full) = -5809.76 / LL (test) = -1186.23 / Rho-sq (test): 0.4028
# NN (30,) / Rep. 7: LL (full) = -5808.04 / LL (test) = -1186.73 / Rho-sq (test): 0.4025
# NN (30,) / Rep. 8: LL (full) = -5805.12 / LL (test) = -1186.27 / Rho-sq (test): 0.4028
# NN (30,) / Rep. 9: LL (full) = -5807.83 / LL (test) = -1186.7 / Rho-sq (test): 0.4026
# NN (30,) / Rep. 10: LL (full) = -5807.01 / LL (test) = -1186.65 / Rho-sq (test): 0.4026
# NN (5, 5) / Rep. 1: LL (full) = -5869.78 / LL (test) = -1196.2 / Rho-sq (test): 0.3978
# NN (5, 5) / Rep. 2: LL (full) = -5876.71 / LL (test) = -1197.07 / Rho-sq (test): 0.3973
# NN (5, 5) / Rep. 3: LL (full) = -5882.32 / LL (test) = -1198.75 / Rho-sq (test): 0.3965
# NN (5, 5) / Rep. 4: LL (full) = -5864.59 / LL (test) = -1195.53 / Rho-sq (test): 0.3981
# NN (5, 5) / Rep. 5: LL (full) = -5872.28 / LL (test) = -1196.43 / Rho-sq (test): 0.3977
# NN (5, 5) / Rep. 6: LL (full) = -5883.26 / LL (test) = -1199.09 / Rho-sq (test): 0.3963
# NN (5, 5) / Rep. 7: LL (full) = -5871.45 / LL (test) = -1195.58 / Rho-sq (test): 0.3981
# NN (5, 5) / Rep. 8: LL (full) = -5852.45 / LL (test) = -1193.16 / Rho-sq (test): 0.3993
# NN (5, 5) / Rep. 9: LL (full) = -5859.17 / LL (test) = -1194.97 / Rho-sq (test): 0.3984
# NN (5, 5) / Rep. 10: LL (full) = -5876.09 / LL (test) = -1197.73 / Rho-sq (test): 0.397
# NN (10, 10) / Rep. 1: LL (full) = -5842.15 / LL (test) = -1191.33 / Rho-sq (test): 0.4002
# NN (10, 10) / Rep. 2: LL (full) = -5838.85 / LL (test) = -1190.11 / Rho-sq (test): 0.4008
# NN (10, 10) / Rep. 3: LL (full) = -5834.44 / LL (test) = -1189.79 / Rho-sq (test): 0.401
# NN (10, 10) / Rep. 4: LL (full) = -5836.58 / LL (test) = -1190.43 / Rho-sq (test): 0.4007
# NN (10, 10) / Rep. 5: LL (full) = -5839.42 / LL (test) = -1191.35 / Rho-sq (test): 0.4002
# NN (10, 10) / Rep. 6: LL (full) = -5834.78 / LL (test) = -1190.98 / Rho-sq (test): 0.4004
# NN (10, 10) / Rep. 7: LL (full) = -5833.12 / LL (test) = -1189.31 / Rho-sq (test): 0.4012
# NN (10, 10) / Rep. 8: LL (full) = -5838.47 / LL (test) = -1190.48 / Rho-sq (test): 0.4007
# NN (10, 10) / Rep. 9: LL (full) = -5834.48 / LL (test) = -1190.16 / Rho-sq (test): 0.4008
# NN (10, 10) / Rep. 10: LL (full) = -5838.81 / LL (test) = -1189.99 / Rho-sq (test): 0.4009
# NN (20, 20) / Rep. 1: LL (full) = -5838.62 / LL (test) = -1191.03 / Rho-sq (test): 0.4004
# NN (20, 20) / Rep. 2: LL (full) = -5826.16 / LL (test) = -1189.25 / Rho-sq (test): 0.4013
# NN (20, 20) / Rep. 3: LL (full) = -5824.8 / LL (test) = -1189.56 / Rho-sq (test): 0.4011
# NN (20, 20) / Rep. 4: LL (full) = -5815.64 / LL (test) = -1186.59 / Rho-sq (test): 0.4026
# NN (20, 20) / Rep. 5: LL (full) = -5821.21 / LL (test) = -1187.39 / Rho-sq (test): 0.4022
# NN (20, 20) / Rep. 6: LL (full) = -5820.91 / LL (test) = -1187.8 / Rho-sq (test): 0.402
# NN (20, 20) / Rep. 7: LL (full) = -5820.5 / LL (test) = -1188.06 / Rho-sq (test): 0.4019
# NN (20, 20) / Rep. 8: LL (full) = -5822.42 / LL (test) = -1188.95 / Rho-sq (test): 0.4014
# NN (20, 20) / Rep. 9: LL (full) = -5819.23 / LL (test) = -1186.67 / Rho-sq (test): 0.4026
# NN (20, 20) / Rep. 10: LL (full) = -5829.99 / LL (test) = -1189.74 / Rho-sq (test): 0.401
# NN (30, 30) / Rep. 1: LL (full) = -5818.13 / LL (test) = -1188.18 / Rho-sq (test): 0.4018
# NN (30, 30) / Rep. 2: LL (full) = -5822.58 / LL (test) = -1190.28 / Rho-sq (test): 0.4008
# NN (30, 30) / Rep. 3: LL (full) = -5827.96 / LL (test) = -1190.0 / Rho-sq (test): 0.4009
# NN (30, 30) / Rep. 4: LL (full) = -5831.87 / LL (test) = -1192.06 / Rho-sq (test): 0.3999
# NN (30, 30) / Rep. 5: LL (full) = -5811.59 / LL (test) = -1186.29 / Rho-sq (test): 0.4028
# NN (30, 30) / Rep. 6: LL (full) = -5825.07 / LL (test) = -1189.7 / Rho-sq (test): 0.401
# NN (30, 30) / Rep. 7: LL (full) = -5819.38 / LL (test) = -1188.97 / Rho-sq (test): 0.4014
# NN (30, 30) / Rep. 8: LL (full) = -5823.7 / LL (test) = -1190.28 / Rho-sq (test): 0.4008
# NN (30, 30) / Rep. 9: LL (full) = -5835.04 / LL (test) = -1192.28 / Rho-sq (test): 0.3997
# NN (30, 30) / Rep. 10: LL (full) = -5818.93 / LL (test) = -1187.9 / Rho-sq (test): 0.4019

# %%
results = pd.DataFrame(np.c_[t_list,lfull_list,ltest_list],columns=['Topology','LL (full)','LL (test)'])
results.to_csv('tables/topology_1_asushared.csv')

# %%
ll_test_df = pd.DataFrame(np.array(ltest_list).reshape((len(network_topologies),R)).T,columns=network_topologies)
r2_df = pd.DataFrame(np.array(r2_list).reshape((len(network_topologies),R)).T,columns=network_topologies)
ll_full_df = pd.DataFrame(np.array(lfull_list).reshape((len(network_topologies),R)).T,columns=network_topologies)

fig, (ax1, ax2, ax3) = plt.subplots(3,1,figsize=(10,15))

ax1.boxplot(ll_test_df,showfliers=False,showmeans=True,labels=ll_test_df.columns)
ax1.set_title('Test')

ax2.boxplot(r2_df,showfliers=False,showmeans=True,labels=r2_df.columns)
ax2.set_title('Rho-squared')

ax3.boxplot(ll_full_df,showfliers=False,showmeans=True,labels=ll_full_df.columns)
ax3.set_title('Full')

plt.show()
